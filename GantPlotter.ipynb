# %%
import plotly.express as px
import pandas as pd
import json
import numpy as np
import altair as alt
alt.renderers.enable('notebook')
alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %%
with open('./dag-extracted.json') as result_json:
    data = json.load(result_json)
ram = '1536' 
df_generated = pd.DataFrame( columns = ['task_name', 'start_time', 'end_time'])
for task in data['tasks']:
    df_generated = df_generated.append({'task_name': task['name'], 'start_time': task['config']['scheduledStartTime'], 'end_time': task['config']['scheduledFinishTime']}, ignore_index=True)
df_generated['task_id'] = df_generated['task_name'] + '_' + df_generated.index.astype(str)

# %%
with open('./dag-extracted.json') as result_json:
#with open('./generated-workflow.json') as result_json:

    data = json.load(result_json)
ram = 'sdbcs' 
#ram = '1536'
df = pd.DataFrame( columns = ['task_name', 'start_time', 'end_time'])
for task in data['tasks']:
    df = df.append({'task_name': task['name'], 'start_time': task['startTime'][str(ram)], 'end_time': task['finishTime'][str(ram)]}, ignore_index=True)
df['task_id'] = df['task_name'] + '_' + df.index.astype(str)

# %%
df[df['task_name'] == 'mConcatFit']
# Out:
#       task_name start_time end_time         task_id
# 262  mConcatFit      20470    23015  mConcatFit_262
# 573  mConcatFit      20476    23020  mConcatFit_573
# 884  mConcatFit      20890    23435  mConcatFit_884

# %%
alt.Chart(df).mark_bar().encode(
    x='start_time',
    x2='end_time',
    y=alt.Y('task_id', 
            sort={"encoding": "x", "order": "descending"}), # Custom sorting
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f77c69e7d514> in <module>
# ----> 1 alt.Chart(df).mark_bar().encode(
#       2     x='start_time',
#       3     x2='end_time',
#       4     y=alt.Y('task_id',
#       5             sort={"encoding": "x", "order": "descending"}), # Custom sorting
#
# NameError: name 'df' is not defined

# %%
alt.Chart(df).mark_bar().encode(
    x='start_time',
    x2='end_time',
    y=alt.Y('task_id', 
            sort={"encoding": "x", "order": "descending"}), # Custom sorting
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x='start_time',
    x2='end_time',
    y=alt.Y('task_id', 
            sort={"encoding": "x", "order": "descending"}), # Custom sorting
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x='start_time',
    x2='end_time',
    y=alt.Y('task_id', 
            sort={"encoding": "x", "order": "descending"}), # Custom sorting
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Scheduled 01.05

# %%
alt.Chart(df_generated).mark_bar().encode(
    x='start_time',
    x2='end_time',
    y=alt.Y('task_id', 
            sort={"encoding": "x", "order": "descending"}),
    color=alt.Color('task_name'),# Custom sorting
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x='start_time',
    x2='end_time',
    y=alt.Y('task_id', 
            sort={"encoding": "x", "order": "descending"}), 
    color=alt.Color('task_name'), )
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x='start_time',
    x2='end_time',
    y=alt.Y('task_id', 
            sort={"encoding": "x", "order": "descending"}), 
    color=alt.Color('task_name'),# Custom sorting
)
# Out:
# alt.Chart(...)
