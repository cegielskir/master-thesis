# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv('./montage-more-data.csv')

# %%
data
# Out:
#         ram  ram_mapped  execution_time_100ms_rounded  \
# 0       128        30.0                          59.0
# 1       128        30.0                           NaN
# 2       128        30.0                          60.0
# 3       128        30.0                           NaN
# 4       128        30.0                         171.0
# ...     ...         ...                           ...
# 16978  2944        15.0                           5.0
# 16979  2944        15.0                          19.0
# 16980  2944        15.0                           5.0
# 16981  2944        15.0                           9.0
# 16982  2944        15.0                         177.0
#
#        execution_time_100ms_rounded_normalized  successed  \
# 0                                     0.202091          0
# 1                                          NaN          1
# 2                                     0.205575          0
# 3                                          NaN          1
# ...

# %%
data['execution_time_100ms_rounded'].hist(figsize=(15,15))

# %%
data['log'] = np.log(data['execution_time_100ms_rounded'])
data['log'].hist(figsize=(15,15))
