# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('./execution_data.json') as result_json:
    data = json.load(result_json)
    
    result_dict = {}
    
    result_dict["task_id"] = []
    result_dict["lambda_time"] = []
    result_dict["download_time"] = []
    result_dict["upload_time"] = []
    result_dict["execution_time"] = []
    result_dict["ram"] = []
    result_dict["cost"] = []
    result_dict["ts"] = []
    
    for record in data['montage_0.35']:
        for record_key in record.keys():
            result_dict[record_key].append(record[record_key])

# %%
df = pd.read_csv("results.csv") 
df['task_core'] = df['task_name'].str.split('_', n = 0, expand = True)[0]
df = df[df['task_core'] == 'mProject']
print(set(df['ram'].values))
plt.figure(figsize=(20,20))
plt.ylim([0, 0.0008])
plt.xlim([0, 30000])
df['Lambda Time[ms]'] = df['lambda_time']
df['Price[$]'] = df['cost']
df['RAM[MB]'] = df['ram']
df = df.groupby('RAM[MB]').mean()
df = df[df['ram'] > 900]
df['RAM[MB]'] = df['ram']
ax = sns.scatterplot(data=df, x='Lambda Time[ms]', y='Price[$]', hue='RAM[MB]')

plt.xlabel("Lambda Time [ms]", size=22)
plt.ylabel("Price [$]", size=22)
plt.xticks(size = 22)
plt.yticks(size = 22)
plt.legend(fontsize=22)

plt.show()
plt.savefig('time-vs-price.pdf')
# Out:
# {1920, 2944, 1408, 2688, 1152, 896, 2432, 2176, 1664, 1536, 2112, 2368, 128, 2496, 2624, 640, 768, 1024, 1280, 1792, 2240, 1088, 1216, 2880, 3008, 1984, 2752, 960, 1856, 2304, 2048, 448, 2560, 2816, 832, 1344, 1472, 1600, 1728}

# %%
df = pd.DataFrame({"task_name" : list(result_dict["task_id"])})
df['lambda_time'] = pd.Series(list(result_dict["lambda_time"]), index=df.index)
df['download_time'] = pd.Series(list(result_dict["download_time"]), index=df.index)
df['upload_time'] = pd.Series(list(result_dict["upload_time"]), index=df.index)
df['execution_time'] = pd.Series(list(result_dict["execution_time"]), index=df.index)
df['ram'] = pd.Series(list(result_dict["ram"]), index=df.index)
df['cost'] = pd.Series(list(result_dict["cost"]), index=df.index)
df['ts'] = pd.Series(list(result_dict["ts"]), index=df.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-23d87493b798> in <module>
# ----> 1 df = pd.DataFrame({"task_name" : list(result_dict["task_id"])})
#       2 df['lambda_time'] = pd.Series(list(result_dict["lambda_time"]), index=df.index)
#       3 df['download_time'] = pd.Series(list(result_dict["download_time"]), index=df.index)
#       4 df['upload_time'] = pd.Series(list(result_dict["upload_time"]), index=df.index)
#       5 df['execution_time'] = pd.Series(list(result_dict["execution_time"]), index=df.index)
#
# NameError: name 'result_dict' is not defined

# %%
df
# Out:
#             task_name  lambda_time  download_time  upload_time  \
# 0          mDiffFit_8          459            379           71
# 1          mDiffFit_8          351            311           34
# 2          mDiffFit_8          747            689           38
# 3         mProject_30        13851            393          240
# 4         mProject_30        21063            327          272
# ...               ...          ...            ...          ...
# 48111    mDiffFit_365          379            221           43
# 48112  mBackground_40         1568            216          223
# 48113  mBackground_65         1862            502          177
# 48114  mBackground_10         2050            597          213
# 48115    mDiffFit_365          281            178           45
#
#        execution_time   ram      cost            ts    task_core
# 0                   8  2944  0.000024  1.603481e+09     mDiffFit
# 1                   5  2944  0.000019  1.603481e+09     mDiffFit
# 2                  16  1152  0.000015  1.603481e+09     mDiffFit
# 3               13216  1920  0.000434  1.603481e+09     mProject
# 4               20463  1152  0.000396  1.603481e+09     mProject
# ...               ...   ...       ...           ...          ...
# 48111             114  3008  0.000020  1.604221e+09     mDiffFit
# 48112            1128  1024  0.000027  1.604221e+09  mBackground
# 48113            1183  1024  0.000032  1.604221e+09  mBackground
# 48114            1251  1024  0.000035  1.604221e+09  mBackground
# 48115              58  2944  0.000014  1.604221e+09     mDiffFit
#
# [48116 rows x 9 columns]

# %%
df = df[df['cost'] != -1]
df.plot.scatter(x='re',
                c='DarkBlue',
                figsize=(20,15))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-4d68960e7ccd> in <module>
#       1 df = df[df['cost'] != -1]
# ----> 2 df.plot.scatter(x='re',
#       3                 c='DarkBlue',
#       4                 figsize=(20,15))
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
df['task_core'] = df['task_name'].str.split('_', n = 0, expand = True)[0]
df = df[df['task_core'] == 'mProject']
print(set(df['ram'].values))
plt.figure(figsize=(20,20))
plt.ylim([0, 0.0008])
plt.xlim([0, 30000])
df['Lambda Time[ms]'] = df['lambda_time']
df['Price[$]'] = df['cost']
df['RAM[MB]'] = df['ram']
df = df.groupby('RAM[MB]').mean()
df['RAM[MB]'] = df['ram']
sns.scatterplot(data=df, x='Lambda Time[ms]', y='Price[$]', hue='RAM[MB]')

# %%
df
# Out:
#             task_name  lambda_time  download_time  upload_time  \
# 0          mDiffFit_8          459            379           71
# 1          mDiffFit_8          351            311           34
# 2          mDiffFit_8          747            689           38
# 3         mProject_30        13851            393          240
# 4         mProject_30        21063            327          272
# ...               ...          ...            ...          ...
# 48111    mDiffFit_365          379            221           43
# 48112  mBackground_40         1568            216          223
# 48113  mBackground_65         1862            502          177
# 48114  mBackground_10         2050            597          213
# 48115    mDiffFit_365          281            178           45
#
#        execution_time   ram      cost            ts    task_core
# 0                   8  2944  0.000024  1.603481e+09     mDiffFit
# 1                   5  2944  0.000019  1.603481e+09     mDiffFit
# 2                  16  1152  0.000015  1.603481e+09     mDiffFit
# 3               13216  1920  0.000434  1.603481e+09     mProject
# 4               20463  1152  0.000396  1.603481e+09     mProject
# ...               ...   ...       ...           ...          ...
# 48111             114  3008  0.000020  1.604221e+09     mDiffFit
# 48112            1128  1024  0.000027  1.604221e+09  mBackground
# 48113            1183  1024  0.000032  1.604221e+09  mBackground
# 48114            1251  1024  0.000035  1.604221e+09  mBackground
# 48115              58  2944  0.000014  1.604221e+09     mDiffFit
#
# [48116 rows x 9 columns]

# %%
df = df[df['task_core'] == 'mProject']
print(set(df['ram'].values))
plt.figure(figsize=(20,20))
plt.ylim([0, 0.0008])
plt.xlim([0, 30000])
df['Lambda Time[ms]'] = df['lambda_time']
df['Price[$]'] = df['cost']
df['RAM[MB]'] = df['ram']
df = df.groupby('RAM[MB]').mean()
df['RAM[MB]'] = df['ram']
sns.scatterplot(data=df, x='Lambda Time[ms]', y='Price[$]', hue='RAM[MB]')
# Out:
# {1920, 2944, 1408, 2688, 1152, 896, 2432, 2176, 1664, 1536, 2112, 2368, 128, 2496, 2624, 640, 768, 1024, 1280, 1792, 2240, 1088, 1216, 2880, 3008, 1984, 2752, 960, 1856, 2304, 2048, 448, 2560, 2816, 832, 1344, 1472, 1600, 1728}
# <ipython-input-15-4968f4ea578e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Lambda Time[ms]'] = df['lambda_time']
# <ipython-input-15-4968f4ea578e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price[$]'] = df['cost']
# <ipython-input-15-4968f4ea578e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RAM[MB]'] = df['ram']
#           lambda_time  download_time  upload_time  execution_time     ram  \
# RAM[MB]
# 128      17266.000000     183.000000   179.000000    16904.000000   128.0
# 448      15905.750000     243.000000   195.750000    15466.000000   448.0
# 640      21303.000000     142.000000   188.000000    20973.000000   640.0
# 768      13473.333333     101.333333   179.666667    13192.000000   768.0
# 832      27379.181818     247.272727   227.909091    26903.818182   832.0
# 896      26986.602679     223.705357   214.464286    26548.008929   896.0
# 960      25184.798165     205.981651   214.944954    24763.752294   960.0
# 1024     23555.220657     180.399061   219.802817    23155.464789  1024.0
# 1088     22392.490196     225.392157   217.235294    21949.490196  1088.0
# 1152     21055.064815     182.450617   207.337963    20665.128086  1152.0
# 1216     19942.432515     157.487730   209.315951    19575.297546  1216.0
# 1280     18978.763636     181.018182   200.509091    18597.145455  1280.0
# 1344     17961.370968     172.903226   202.306452    17586.209677  1344.0
# 1408     17287.459770     176.103448   199.448276    16911.620690  1408.0
# 1472     16455.032787     175.475410   191.721311    16087.262295  1472.0
# 1536     15987.983333     172.716667   191.450000    15623.516667  1536.0
# 1600     15280.621118     156.906832   185.695652    14937.633540  1600.0
# 1664     14978.560538     155.237668   192.708520    14630.188341  1664.0
# 1728     14365.363208     140.551887   189.363208    14035.117925  1728.0
# 1792     13684.380952     137.222222   193.009524    13353.895238  1792.0
# 1856     13715.183333     154.800000   201.900000    13358.200000  1856.0
# 1920     13676.268908     132.403361   197.739496    13345.798319  1920.0
# 1984     13692.280000     140.693333   192.084444    13359.111111  1984.0
# 2048     13643.269841     155.888889   186.682540    13300.333333  2048.0
# 2112     13615.461538     130.576923   186.932692    13297.596154  2112.0
# 2176     13629.060606     149.242424   190.242424    13289.020202  2176.0
# 2240     13577.528571     137.114286   182.685714    13257.307143  2240.0
# 2304     13654.030418     142.311787   185.083650    13326.292776  2304.0
# 2368     13576.473684     145.789474   181.561404    13248.807018  2368.0
# 2432     13619.755556     152.966667   190.544444    13275.722222  2432.0
# 2496     13603.323741     124.312950   187.712230    13291.003597  2496.0
# 2560     13654.853383     128.481203   195.969925    13330.037594  2560.0
# 2624     13597.953125     136.093750   187.109375    13274.265625  2624.0
# 2688     13609.234694     145.755102   183.285714    13279.775510  2688.0
# 2752     13623.923077     123.046154   186.441026    13314.097436  2752.0
# 2816     13593.140244     135.500000   190.713415    13266.451220  2816.0
# 2880     13548.951724     119.531034   181.096552    13247.910345  2880.0
# 2944     13567.651613     126.883871   185.561290    13254.800000  2944.0
# 3008     13534.645161     132.451613   183.096774    13218.774194  3008.0
#
#              cost            ts  Lambda Time[ms]  Price[$]
# RAM[MB]
# 128      0.000036  1.604209e+09     17266.000000  0.000036
# 448      0.000116  1.604189e+09     15905.750000  0.000116
# 640      0.000223  1.604177e+09     21303.000000  0.000223
# 768      0.000169  1.604205e+09     13473.333333  0.000169
# 832      0.000371  1.604193e+09     27379.181818  0.000371
# 896      0.000394  1.604084e+09     26986.602679  0.000394
# 960      0.000394  1.604190e+09     25184.798165  0.000394
# 1024     0.000393  1.604193e+09     23555.220657  0.000393
# 1088     0.000397  1.604184e+09     22392.490196  0.000397
# 1152     0.000396  1.603729e+09     21055.064815  0.000396
# 1216     0.000396  1.604185e+09     19942.432515  0.000396
# 1280     0.000396  1.604183e+09     18978.763636  0.000396
# 1344     0.000394  1.604183e+09     17961.370968  0.000394
# 1408     0.000397  1.603878e+09     17287.459770  0.000397
# 1472     0.000396  1.604188e+09     16455.032787  0.000396
# 1536     0.000401  1.604183e+09     15987.983333  0.000401
# 1600     0.000399  1.604192e+09     15280.621118  0.000399
# 1664     0.000407  1.604060e+09     14978.560538  0.000407
# 1728     0.000405  1.604197e+09     14365.363208  0.000405
# 1792     0.000401  1.604183e+09     13684.380952  0.000401
# 1856     0.000416  1.604183e+09     13715.183333  0.000416
# 1920     0.000429  1.604112e+09     13676.268908  0.000429
# 1984     0.000444  1.604189e+09     13692.280000  0.000444
# 2048     0.000456  1.604186e+09     13643.269841  0.000456
# 2112     0.000470  1.604191e+09     13615.461538  0.000470
# 2176     0.000484  1.603921e+09     13629.060606  0.000484
# 2240     0.000497  1.604189e+09     13577.528571  0.000497
# 2304     0.000514  1.604185e+09     13654.030418  0.000514
# 2368     0.000525  1.604184e+09     13576.473684  0.000525
# 2432     0.000541  1.603927e+09     13619.755556  0.000541
# 2496     0.000555  1.604187e+09     13603.323741  0.000555
# 2560     0.000571  1.604183e+09     13654.853383  0.000571
# 2624     0.000583  1.604190e+09     13597.953125  0.000583
# 2688     0.000598  1.603878e+09     13609.234694  0.000598
# 2752     0.000612  1.604192e+09     13623.923077  0.000612
# 2816     0.000625  1.604190e+09     13593.140244  0.000625
# 2880     0.000637  1.604193e+09     13548.951724  0.000637
# 2944     0.000653  1.604032e+09     13567.651613  0.000653
# 3008     0.000665  1.604183e+09     13534.645161  0.000665

# %%
new_df = df[df['task_core'] == 'mAdd']
# new_df = new_df[new_df['ram'] == ]
new_df = df[df['cost'] < 0.00010]
new_df = df[df['lambda_time'] < 4_000]
plt.figure(figsize=(20,20))
sns.scatterplot(data=new_df, x='lambda_time', y='cost', hue='ram')

# %%
df.to_csv('./results.csv', index = False, header = True)

# %%
df['reward'] = (df['lambda_time'] +  35_000_000 * df['cost']) / 40_000
#df['new_cost'] = 35_000_000 * df['cost']

# %%
plt.figure(figsize=(20,20))
sns.scatterplot(data=df, x='reward', hue='task_core')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-131e33a2550d> in <module>
#       1 plt.figure(figsize=(20,20))
# ----> 2 sns.scatterplot(data=df, x='reward', hue='task_core')
#
# ~/.local/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1388                 legend="brief", ax=None, **kwargs):
#    1389
# -> 1390     p = _ScatterPlotter(
#    1391         x=x, y=y, hue=hue, style=style, size=size, data=data,
#    1392         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ~/.local/lib/python3.8/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     883                  legend=None):
#     884
# --> 885         plot_data = self.establish_variables(
#     886             x, y, hue, size, style, units, data
#     887         )
#
# ~/.local/lib/python3.8/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     159             err = ("Either both or neither of `x` and `y` must be specified "
#     160                    "(but try passing to `data`, which is more flexible).")
# --> 161             raise ValueError(err)
#     162
#     163         # ---- Post-processing
#
# ValueError: Either both or neither of `x` and `y` must be specified (but try passing to `data`, which is more flexible).

# %%
new_df = df[df['task_core'] =='mBgModel']
plt.figure( figsize=(20,20))
new_df.hist(column = 'reward',bins=50, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb509f84790>]],
#       dtype=object)

# %%
df['new_upload_time'] = df['upload_time'] / 100
df.astype({'new_upload_time': 'int32'})
# Out:
#            task_name  lambda_time  download_time  upload_time  execution_time  \
# 0         mDiffFit_8          459            379           71               8
# 1         mDiffFit_8          351            311           34               5
# 2         mDiffFit_8          747            689           38              16
# 3        mProject_30        13851            393          240           13216
# 4        mProject_30        21063            327          272           20463
# ...              ...          ...            ...          ...             ...
# 6313    mDiffFit_230         2699           2471          128             120
# 6314      mDiffFit_4         2987           2620          259             100
# 6315  mBackground_80         1456            300          223             933
# 6316    mDiffFit_287         5487           5019          219             239
# 6317  mBackground_12         1038            198          186             654
#
#        ram      cost                  ts    task_core    reward      new_cost  \
# 0     2944  0.000024    1603481324.07255     mDiffFit  0.032439    838.543344
# 1     2944  0.000019  1603481448.9180465     mDiffFit  0.025546    670.834675
# 2     1152  0.000015  1603481452.4749908     mDiffFit  0.031800    525.001050
# 3     1920  0.000434  1603481469.2875435     mProject  0.726354  15203.155406
# 4     1152  0.000396   1603481490.998285     mProject  0.872748  13846.902694
# ...    ...       ...                 ...          ...       ...           ...
# 6313   128  0.000006  1603528338.6676273     mDiffFit  0.072397    196.875394
# 6314   128  0.000006   1603528397.036302     mDiffFit  0.080144    218.750438
# 6315  1408  0.000034  1603528399.1880345  mBackground  0.066478   1203.127406
# 6316   128  0.000011   1603528471.686384     mDiffFit  0.147201    401.042469
# 6317  1920  0.000034  1603528473.4517722  mBackground  0.056028   1203.127406
#
#       new_upload_time
# 0                   0
# 1                   0
# 2                   0
# 3                   2
# 4                   2
# ...               ...
# 6313                1
# 6314                2
# 6315                2
# 6316                2
# 6317                1
#
# [6318 rows x 12 columns]

# %%
df.groupby('task_core').count()
# Out:
#              task_name  lambda_time  download_time  upload_time  \
# task_core
# mAdd               244          244            244          244
# mBackground       7081         7081           7081         7081
# mBgModel           255          255            255          255
# mConcatFit         255          255            255          255
# mDiffFit         33941        33941          33941        33941
# mImgtbl            211          211            211          211
# mProject          5816         5816           5816         5816
# mViewer            313          313            313          313
#
#              execution_time    ram   cost     ts  reward
# task_core
# mAdd                    244    244    244    244     244
# mBackground            7081   7081   7081   7081    7081
# mBgModel                255    255    255    255     255
# mConcatFit              255    255    255    255     255
# mDiffFit              33941  33941  33941  33941   33941
# mImgtbl                 211    211    211    211     211
# mProject               5816   5816   5816   5816    5816
# mViewer                 313    313    313    313     313
