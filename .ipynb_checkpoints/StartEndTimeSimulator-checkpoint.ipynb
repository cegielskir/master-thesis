# %%
import pandas as pd
import keras
import tensorflow as tf
import random
import decimal
import json
from random import randrange, uniform
from sklearn import preprocessing
import keras.backend as K




MAX_TIME =  30000 * 3008 

TASK_NAME_LIST = ['mProject', 'mDiffFit', 'mConcatFit', 'mBgModel', 'mBackground', 'mImgtbl', 'mAdd', 'mViewer']

RAM_MAP = {128:30.0,
           192:39.0,
           256:6.0,
           320:28.0,
           384:36.0,
           448:11.0,
           512:18.0,
           576:9.0,
           640:32.0,
           704:17.0,
           768:3.0,
           832:8.0,
           896:24.0,
           960:34.0,
           1024:1.0,
           1088:44.0,
           1152:16.0,
           1216:13.0,
           1280:12.0,
           1344:27.0,
           1408:33.0,
           1472:14.0,
           1536:22.0,
           1600:7.0,
           1664:20.0,
           1728:37.0,
           1792:40.0,
           1856:35.0,
           1920:41.0,
           1984:46.0,
           2048:29.0,
           2112:21.0,
           2176:23.0,
           2240:26.0,
           2304:25.0,
           2368:2.0,
           2432:45.0,
           2496:43.0,
           2560:10.0,
           2624:42.0,
           2688:31.0,
           2752:4.0,
           2816:38.0,
           2880:5.0,
           2944:15.0,
           3008:19.0}
# Out:
# Using TensorFlow backend.

# %%
def map_ram(ram):
    return RAM_MAP[ram]

# %%
def map_task_type(task_type_name):
    return TASK_NAME_LIST.index(task_type_name)

# %%
def get_previous_task_type(task_name):
    return TASK_NAME_LIST[TASK_NAME_LIST.index(task_name) -1]

# %%
def next_ram(ram):
    ram_list = list(range(128, 3072 ,64))
    cur_index = ram_list.index(ram)
    if cur_index == 45:
        return 3008
    else:
        return ram_list[cur_index + 1]

# %%
def previous_ram(ram):
    ram_list = list(range(128, 3072 ,64))
    cur_index = ram_list.index(ram)
    if cur_index == 0:
        return 128
    else:
        return ram_list[cur_index - 1]

# %%
def getPredictedExecutionTime(ram, task_type_name, workflow_size, df_x, df_x_failed, model, model_failed, iteration, mview, hyperflow_model):
    ins_from = -1.0
    ins_to = 1
    if mview == True:
        ins_from = 0.001
        ins_to = 1.1
        
    if hyperflow_model:
        normalize = (78425.0 - 484.0) + 484.0
    else:
        normalize = (28637.0 - 169.0) + 169.0
            
    mapped_ram_normalized = (ram - 128) / ( 3008 - 128)
    #print(mapped_ram_normalized)
    mapped_ram = map_ram(ram)
    mapped_task_type_normalized = round(map_task_type(task_type_name) / 7, 8)
    #print(mapped_task_type_normalized)
    mapped_task_type = map_task_type(task_type_name)
    #print(df_x_failed[(df_x_failed['ram_mapped'] == mapped_ram) & (df_x_failed['task_type'] == mapped_task_type) & (df_x_failed['workflow_size_mapped'] == workflow_size)].index.values)
    ids_failed = list(df_x_failed[(abs(df_x_failed['ram'] - mapped_ram_normalized) < 0.0001)  & 
                                  (abs(df_x_failed['task_type'] - mapped_task_type_normalized) < 0.0001) & 
                                  (abs(df_x_failed['workflow_size_mapped'] - workflow_size) < 0.0001)].index.values)
    #print(df_x[(df_x['ram_mapped'] == mapped_ram) & (df_x['task_type'] == mapped_task_type) & (df_x['workflow_size_mapped'] == workflow_size)])
    #print(df_x[abs(df_x['task_type'] - mapped_task_type_normalized) < 0.0001])
    
    ids = list(df_x[(abs(df_x['ram'] - mapped_ram_normalized) < 0.0001 ) & 
                    (abs(df_x['task_type'] - mapped_task_type_normalized) < 0.0001) & 
                    (df_x['workflow_size_mapped'] == workflow_size) &
                    (df_x['count_in_ln'] > ins_from) &
                    (df_x['count_in_ln'] <= ins_to)].index.values) 
    
    #print(ids)
    failed_chance = model_failed.predict(df_x_failed.loc[[random.choice(ids_failed)]].values)[0][0]
    if task_type_name == 'mBgModel':
        if ram < 1000:
            failed_chance = failed_chance + 0.7
        else:
            failed_chance = failed_chance - 0.3
    if (failed_chance > 0.7) or (task_type_name == 'mConcatFit' and ram == 128):
        return MAX_TIME / ram
    if (len(ids) == 0):
        return MAX_TIME / ram    
    else:
        value = df_x.loc[[random.choice(ids)]]
        
        predicted_value = model.predict(value.values)[0][0]
#         if task_type_name == 'mAdd' or task_type_name == 'mBackground' or task_type_name == 'mBgModel':
#             perc = random.randint(5, 10)
#             predicted_value = predicted_value * ( 100 + perc) / 100
        return predicted_value * normalize

# %%
failed_model = tf.keras.models.load_model('./best-failed-model-normalized-true')
model = tf.keras.models.load_model('./best-model-hyperflow-final-new')
hyperflow_model = tf.keras.models.load_model('./best-model-final-hyperflow')
for ram in list(range(128, 3072 ,64)):
    print("RAM " + str(ram))
    print(getPredictedExecutionTime(ram, 'mDiffFit', 0, get_x(), get_x_failed(), model, failed_model, 0, False, False))
    print(getPredictedExecutionTime(ram, 'mDiffFit', 0, get_x(), get_x_failed(), hyperflow_model, failed_model, 0, False, True))
    print("==========")
# Out:
# RAM 128
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f1a2e9085bd8> in <module>
#       4 for ram in list(range(128, 3072 ,64)):
#       5     print("RAM " + str(ram))
# ----> 6     print(getPredictedExecutionTime(ram, 'mDiffFit', 0, get_x(), get_x_failed(), model, failed_model, 0, False, False))
#       7     print(getPredictedExecutionTime(ram, 'mDiffFit', 0, get_x(), get_x_failed(), hyperflow_model, failed_model, 0, False, True))
#       8     print("==========")
#
# NameError: name 'get_x' is not defined

# %%
def decorate_workflow(workflow):
    df_x = get_x()
    df_x_failed = get_x_failed()
    model = tf.keras.models.load_model('./best-model-hyperflow-final-new')
    hyperflow_model = tf.keras.models.load_model('./best-model-hyperflow-final-new-hyperflow')

    failed_model = tf.keras.models.load_model('./best-failed-model-normalized')
    tasks = workflow['tasks']
    max_tasks_start_times = {
        'mProject': {}, 
        'mDiffFit': {}, 
        'mConcatFit': {}, 
        'mBgModel': {}, 
        'mBackground': {}, 
        'mImgtbl': {}, 
        'mAdd': {}, 
        'mViewer': {}    }
    min_tasks_finish_times = {
        'mProject': {}, 
        'mDiffFit': {}, 
        'mConcatFit': {}, 
        'mBgModel': {}, 
        'mBackground': {}, 
        'mImgtbl': {}, 
        'mAdd': {}, 
        'mViewer': {}    }
    for task_type in TASK_NAME_LIST:
        for ram in list(range(128, 3072 ,64)):
            max_tasks_start_times[task_type][str(ram)] = 0
            min_tasks_finish_times[task_type][str(ram)] = 99999999
    mdiff_times = {}
    mdiff_hyperflow_times = {}
#     for ram in list(range(128, 3072 ,64)):        
#         times = []
#         h_times = []
#         for i in range(0, 50):
#             times.append(getPredictedExecutionTime(ram, 'mDiffFit', 0.0, df_x, df_x_failed, model, failed_model, 0, False, False))
#             h_times.append(getPredictedExecutionTime(ram, 'mDiffFit', 0.0, df_x, df_x_failed, hyperflow_model, failed_model, 0, False, True))
#         mdiff_times[ram] = max(times)
#         mdiff_hyperflow_times[ram] = max(h_times)

    whole_calculation = len(workflow['tasks']) * len(list(range(128, 3072 ,64)))
    current_calculation = 0
    for task_type in TASK_NAME_LIST:
        print(task_type)
        inc_time = 0
        for task in workflow['tasks']:
            if task['name'] == task_type:
                inc_time += 6
                for ram in list(range(128, 3072 ,64)):
                            
                #for ram in [1536]:
                    current_calculation += 1
                    current_task_predecessors = find_predecessor(workflow, task)
                    mview = False
                    if len(task['ins']) > 1:
                        mview = True
#                     if task['name'] == 'mDiffFit':
#                         time = mdiff_times[ram]
#                         hyperflow_time = mdiff_hyperflow_times[ram]
#                     else:
                    time = getPredictedExecutionTime(ram, task['name'], 0.0, df_x, df_x_failed, model, failed_model, 0, mview, False)
                    hyperflow_time = getPredictedExecutionTime(ram, task['name'], 0.0, df_x, df_x_failed, hyperflow_model, failed_model, 0, mview, True)
                    delay = max(10, hyperflow_time - time)
                    finish_times = []
                    if 'startTime' not in task:
                        task['startTime'] = {}
                    if 'finishTime' not in task:
                        task['finishTime'] = {}
                    for predecessor in current_task_predecessors:
                        finish_times.append(predecessor['finishTime'][str(ram)])
                    if len(current_task_predecessors) == 0:
                        task['startTime'][str(ram)] = inc_time
                        task['finishTime'][str(ram)] = inc_time + int(time)
                    else:   
                        max_finish_time = max(finish_times)
                        start_time = max(inc_time + max_finish_time, max_tasks_start_times[get_previous_task_type(task_type)][str(ram)] + 20)
                        task['startTime'][str(ram)] =  start_time
                        task['finishTime'][str(ram)] = start_time + int(time)
                    min_tasks_finish_times[task_type][str(ram)] = min(task['finishTime'][str(ram)], min_tasks_finish_times[task_type][str(ram)])
                    max_tasks_start_times[task_type][str(ram)] = max(task['startTime'][str(ram)], max_tasks_start_times[task_type][str(ram)])
                    
    with open('./generated-workflow.json', 'w+') as result_json:
        json.dump(workflow, result_json, indent=4)

# %%
def get_x():
    df_results = pd.read_csv('./montage-final.csv')
    df_results = df_results[df_results['successed'] == 0]
    del df_results['task_id']
    del df_results['workflow']

    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(df_results.values)
    df_results = pd.DataFrame(x_scaled, columns=df_results.columns)
    df_y = df_results['lambda_time']
    del df_results['lambda_time_100ms_rounded']
    del df_results['download_time_100ms_rounded_normalized']
    del df_results['ram_mapped']
    del df_results['lambda_time']
    del df_results['execution_time_100ms_rounded']
    del df_results['execution_time_100ms_rounded_normalized']
    del df_results['upload_time_100ms_rounded']
    del df_results['upload_time_100ms_rounded_normalized']
    del df_results['download_time_100ms_rounded']
    del df_results['successed']
    del df_results['lambda_time_100ms_rounded_normalized']
    del df_results['workflow_size']
    del df_results['iteration']
    del df_results['Unnamed: 0']
    df_results = df_results.reset_index(drop=True)
    return df_results

# %%
sum([1,2,3])
# Out:
# 6

# %%
def get_x_with_time():
    df_core = pd.read_csv('./results-montage.csv')
    df_more_data = pd.read_csv('./montage-more-data.csv')
    df_results = pd.concat([df_core, df_more_data])
    df_results = df_results[df_results['successed'] == 0]
    del df_results['download_time_100ms_rounded_normalized']
    del df_results['ram']
    del df_results['execution_time_100ms_rounded']
    del df_results['execution_time_100ms_rounded_normalized']
    del df_results['upload_time_100ms_rounded']
    del df_results['upload_time_100ms_rounded_normalized']
    del df_results['download_time_100ms_rounded']
    del df_results['task_id']
    del df_results['successed']
    del df_results['lambda_time_100ms_rounded_normalized']
    del df_results['workflow']
    del df_results['workflow_size']
    return df_results

# %%
def get_x_failed():
# DO ZMIANY
    df_results = pd.read_csv('./x_failed_normalized.csv')
    return df_results

# %%
def find_predecessor(workflow, the_task):
    predecessors = []
    for task in workflow['tasks']:
        if any(x in task['outs'] for x in the_task['ins']):
            predecessors.append(task)
    return predecessors

# %%
def decorate_workflow_all_ram(data):
    for ram in list(range(128, 3072 ,64)):
        print(ram)
        decorate_workflow(data, ram)
    with open('./generated-workflow.json', 'w+') as result_json:
        json.dump(data, result_json, indent=4)

# %%
def fix_generated_times(task):
    for ram in list(range(128, 3072 ,64)):
        start_time = task['startTime'][str(ram)]
        end_time = task['finishTime'][str(ram)]
        total_time = end_time - start_time
        previous_ram_total_time = get_total_time(task, previous_ram(ram))
        next_ram_total_time = get_total_time(task, next_ram(ram))

        if (total_time < (0.9 * min(previous_ram_total_time, next_ram_total_time))) or (total_time > (1.1 * max(previous_ram_total_time, next_ram_total_time))):
            task['finishTime'][str(ram)] = int(start_time + (previous_ram_total_time + next_ram_total_time)/2)

# %%
def get_total_time(task, ram):
    start_time = task['startTime'][str(ram)]
    end_time = task['finishTime'][str(ram)]
    return end_time - start_time

# %%
def find_predecessor(workflow, the_task):
    predecessors = []
    for task in workflow['tasks']:
        if any(x in task['outs'] for x in the_task['ins']):
            predecessors.append(task)
    return predecessors

# %%
df = get_x()
df[df['task_type'] == 3][df['ram_mapped'] == 30]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ram_mapped'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-67b79ab80891> in <module>
#       1 df = get_x()
# ----> 2 df[df['task_type'] == 3][df['ram_mapped'] == 30]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ram_mapped'

# %%
df_failed = get_x_failed()
df_x_failed[(df_x['ram_mapped'] == mapped_ram) & (df_x['task_type'] == mapped_task_type) & (df_x['workflow_size_mapped'] == workflow_size)]

# %%
with open('./workflow.json') as result_json:
    data = json.load(result_json)
decorate_workflow(data)
# Out:
# mProject
# mDiffFit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-f29add83fcec> in <module>
#       1 with open('./workflow.json') as result_json:
#       2     data = json.load(result_json)
# ----> 3 decorate_workflow(data)
#
# <ipython-input-24-db67fdd95deb> in decorate_workflow(workflow)
#      60 #                         hyperflow_time = mdiff_hyperflow_times[ram]
#      61 #                     else:
# ---> 62                     time = getPredictedExecutionTime(ram, task['name'], 0.0, df_x, df_x_failed, model, failed_model, 0, mview, False)
#      63                     hyperflow_time = getPredictedExecutionTime(ram, task['name'], 0.0, df_x, df_x_failed, hyperflow_model, failed_model, 0, mview, True)
#      64 #                     delay = max(10, hyperflow_time - time)
#
# <ipython-input-7-2e0f999057c6> in getPredictedExecutionTime(ram, task_type_name, workflow_size, df_x, df_x_failed, model, model_failed, iteration, mview, hyperflow_model)
#      24     #print(df_x[abs(df_x['task_type'] - mapped_task_type_normalized) < 0.0001])
#      25
# ---> 26     ids = list(df_x[(abs(df_x['ram'] - mapped_ram_normalized) < 0.0001 ) &
#      27                     (abs(df_x['task_type'] - mapped_task_type_normalized) < 0.0001) &
#      28                     (df_x['workflow_size_mapped'] == workflow_size) &
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     551
#     552         res_values = logical_op(lvalues, rvalues, op)
# --> 553         return _construct_result(self, res_values, index=self.index, name=res_name)
#     554
#     555     wrapper.__name__ = op_name
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/__init__.py in _construct_result(left, result, index, name)
#     476     # We do not pass dtype to ensure that the Series constructor
#     477     #  does inference in the case where `result` has object-dtype.
# --> 478     out = left._constructor(result, index=index)
#     479     out = out.__finalize__(left)
#     480
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     303                     data = data.copy()
#     304             else:
# --> 305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
#     307                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     496                 subarr = np.array(data, dtype=object, copy=copy)
#     497
# --> 498         if is_object_dtype(subarr.dtype) and not is_object_dtype(dtype):
#     499             inferred = lib.infer_dtype(subarr, skipna=False)
#     500             if inferred in {"interval", "period"}:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_object_dtype(arr_or_dtype)
#     247     False
#     248     """
# --> 249     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#     250
#     251
#
# ~/.local/lib/python3.8/site-packages/pandas/core/dtypes/common.py in _is_dtype_type(arr_or_dtype, condition)
#    1725
#    1726     # fastpath
# -> 1727     if isinstance(arr_or_dtype, np.dtype):
#    1728         return condition(arr_or_dtype.type)
#    1729     elif isinstance(arr_or_dtype, type):
#
# KeyboardInterrupt:

# %%
with open('./generated-workflow.json') as result_json:
    data = json.load(result_json)
for task in data['tasks']:
    for ram in list(range(128, 3072 ,64)):
        if ram % 128 == 64:
            if str(ram) in task['startTime']:
                print(ram)
                del task['startTime'][str(ram)]
                del task['finishTime'][str(ram)]
            
with open('./generated-workflow.json', 'w+') as result_json:
    json.dump(data, result_json, indent=4)
# Out:
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# ...
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008
# 192
# 320
# 448
# 576
# 704
# 832
# 960
# 1088
# 1216
# 1344
# 1472
# 1600
# 1728
# 1856
# 1984
# 2112
# 2240
# 2368
# 2496
# 2624
# 2752
# 2880
# 3008

# %%
for ram in list(range(128, 3072 ,64)):
    if ram % 128 == 0:
        print('"' + str(ram) + '": ' + str('{0:.8f}'.format(0.00000021 * ram / 128)) + ',')
# Out:
# "128": 0.00000021,
# "256": 0.00000042,
# "384": 0.00000063,
# "512": 0.00000084,
# "640": 0.00000105,
# "768": 0.00000126,
# "896": 0.00000147,
# "1024": 0.00000168,
# "1152": 0.00000189,
# "1280": 0.00000210,
# "1408": 0.00000231,
# "1536": 0.00000252,
# "1664": 0.00000273,
# "1792": 0.00000294,
# "1920": 0.00000315,
# "2048": 0.00000336,
# "2176": 0.00000357,
# "2304": 0.00000378,
# "2432": 0.00000399,
# "2560": 0.00000420,
# "2688": 0.00000441,
# "2816": 0.00000462,
# "2944": 0.00000483,

# %%
for ram in list(range(128, 3072 ,64)):
    if ram % 128 == 0:
        print('"' + str(ram) + '",')
# Out:
# "128",
# "256",
# "384",
# "512",
# "640",
# "768",
# "896",
# "1024",
# "1152",
# "1280",
# "1408",
# "1536",
# "1664",
# "1792",
# "1920",
# "2048",
# "2176",
# "2304",
# "2432",
# "2560",
# "2688",
# "2816",
# "2944",

# %%
df_x = get_x_with_time()
df_x[(df_x['ram_mapped'] == 18.0) & (df_x['task_type'] == 7) & (df_x['workflow_size_mapped'] == 1.0)]
# Out:
#       ram_mapped  lambda_time_100ms_rounded  task_count_log  \
# 7336        18.0                      102.0         0.60206
# 7574        18.0                       50.0         0.60206
# 7812        18.0                      101.0         0.60206
# 8050        18.0                       49.0         0.60206
# 2224        18.0                       51.0         0.60206
# ...          ...                        ...             ...
# 2567        18.0                      110.0         0.60206
# 2576        18.0                       53.0         0.60206
# 2577        18.0                       45.0         0.60206
# 2579        18.0                       54.0         0.60206
# 2583        18.0                      104.0         0.60206
#
#       all_tasks_count_log  task_type  min_size_in_ln  max_size_in_ln  \
# 7336             2.970347          7       16.357402       16.357402
# 7574             2.970347          7       16.357402       16.357402
# 7812             2.970347          7       16.357402       16.357402
# 8050             2.970347          7       16.357402       16.357402
# 2224             2.970347          7       16.357402       16.357402
# ...                   ...        ...             ...             ...
# 2567             2.970347          7       16.357402       16.357402
# 2576             2.970347          7       16.357402       16.357402
# 2577             2.970347          7       16.357402       16.357402
# 2579             2.970347          7       16.357402       16.357402
# 2583             2.970347          7       16.357402       16.357402
#
#       avg_size_in_ln  count_in_ln  sum_in_ln  min_size_out_ln  \
# 7336       16.357402     1.098612  17.456015        15.063245
# 7574       16.357402     0.000000  16.357402        13.811694
# 7812       16.357402     1.098612  17.456015        15.063245
# 8050       16.357402     0.000000  16.357402        13.811694
# 2224       16.357402     0.000000  16.357402        13.826876
# ...              ...          ...        ...              ...
# 2567       16.357402     1.098612  17.456015        15.063245
# 2576       16.357402     0.000000  16.357402        13.826876
# 2577       16.357402     0.000000  16.357402        13.654701
# 2579       16.357402     0.000000  16.357402        13.811694
# 2583       16.357402     1.098612  17.456015        15.063245
#
#       max_size_out_ln  avg_size_out_ln  count_out  sum_out_ln  \
# 7336        15.063245        15.063245          1   15.063245
# 7574        13.811694        13.811694          1   13.811694
# 7812        15.063245        15.063245          1   15.063245
# 8050        13.811694        13.811694          1   13.811694
# 2224        13.826876        13.826876          1   13.826876
# ...               ...              ...        ...         ...
# 2567        15.063245        15.063245          1   15.063245
# 2576        13.826876        13.826876          1   13.826876
# 2577        13.654701        13.654701          1   13.654701
# 2579        13.811694        13.811694          1   13.811694
# 2583        15.063245        15.063245          1   15.063245
#
#       exec_file_size_ln  workflow_size_mapped
# 7336          15.433209                   1.0
# 7574          15.433209                   1.0
# 7812          15.433209                   1.0
# 8050          15.433209                   1.0
# 2224          15.433209                   1.0
# ...                 ...                   ...
# 2567          15.433209                   1.0
# 2576          15.433209                   1.0
# 2577          15.433209                   1.0
# 2579          15.433209                   1.0
# 2583          15.433209                   1.0
#
# [96 rows x 17 columns]

# %%
def find_predecessor(workflow, the_task):
    predecessors = []
    for task in workflow['tasks']:
        if any(x in task['outs'] for x in the_task['ins']):
            predecessors.append(task)
    return predecessors

# %%
df_results = pd.read_csv('./results-montage.csv')

# %%
df_x = get_x()
model = tf.keras.models.load_model('./best-model-more-data')
getPredictedExecutionTime(1536, 'mBgModel', 1.0, df_x, model, 0)
# Out:
# in method
# In else
# 256.5726

# %%
df_results[df_results['task_type'] == 8][['task_type', 'task_id']]
# Out:
# Empty DataFrame
# Columns: [task_type, task_id]
# Index: []

# %%
df_results = df_results[df_results['successed'] == 0]
df_y = df_results['lambda_time_100ms_rounded']
del df_results['lambda_time_100ms_rounded']
del df_results['download_time_100ms_rounded_normalized']
del df_results['ram']
del df_results['execution_time_100ms_rounded']
del df_results['execution_time_100ms_rounded_normalized']
del df_results['upload_time_100ms_rounded']
del df_results['upload_time_100ms_rounded_normalized']
del df_results['download_time_100ms_rounded']
del df_results['task_id']
del df_results['successed']
del df_results['lambda_time_100ms_rounded_normalized']
del df_results['workflow']
del df_results['workflow_size']
df_x = df_results

# %%
df_x = df_results

# %%
df_x[(df_x['ram_mapped'] == 19.0) & (df_x['task_type'] == 3) & (df_x['workflow_size_mapped'] == 2.0)]
# Out:
#        ram_mapped  task_count_log  all_tasks_count_log  task_type  \
# 81360        19.0        0.477121             2.791691          3
# 81443        19.0        0.477121             2.791691          3
# 81503        19.0        0.477121             2.791691          3
# 81979        19.0        0.477121             2.791691          3
# 82062        19.0        0.477121             2.791691          3
#
#        min_size_in_ln  max_size_in_ln  avg_size_in_ln  count_in_ln  sum_in_ln  \
# 81360        9.364605       10.293399        9.933168     0.693147  10.626315
# 81443        9.364605       10.293399        9.933168     0.693147  10.626315
# 81503        9.364605       10.293399        9.933168     0.693147  10.626315
# 81979        9.364605       10.293399        9.933168     0.693147  10.626315
# 82062        9.364605       10.293399        9.933168     0.693147  10.626315
#
#        min_size_out_ln  max_size_out_ln  avg_size_out_ln  count_out  \
# 81360         7.441907         7.441907         7.441907          1
# 81443         7.441907         7.441907         7.441907          1
# 81503         7.441907         7.441907         7.441907          1
# 81979         7.441907         7.441907         7.441907          1
# 82062         7.441907         7.441907         7.441907          1
#
#        sum_out_ln  exec_file_size_ln  workflow_size_mapped
# 81360    7.441907          13.733667                   2.0
# 81443    7.441907          13.733667                   2.0
# 81503    7.441907          13.733667                   2.0
# 81979    7.441907          13.733667                   2.0
# 82062    7.441907          13.733667                   2.0

# %%
ids = list(df_x[(df_x['ram_mapped'] == 19.0) & (df_x['task_type'] == 0) & (df_x['workflow_size_mapped'] == 2.0)].index.values)

# %%
ids
# Out:
# [81328,
#  81333,
#  81334,
#  81342,
#  81343,
#  81351,
#  81353,
#  81357,
#  81362,
#  81364,
#  81369,
#  81371,
#  81378,
#  81396,
#  81398,
#  81402,
#  81410,
#  81416,
#  81419,
#  81420,
#  81424,
#  81437,
#  81444,
#  81448,
#  81463,
#  81465,
#  81470,
#  81474,
#  81481,
#  81482,
#  81487,
#  81488,
#  81489,
#  81492,
#  81521,
#  81524,
#  81526,
#  81531,
#  81561,
#  81568,
#  81573,
#  81576,
#  81586,
#  81590,
#  81591,
#  81595,
#  81600,
#  81602,
#  81617,
#  81631,
#  81636,
#  81652,
#  81653,
#  81657,
#  81665,
#  81670,
#  81688,
#  81708,
#  81710,
#  81717,
#  81719,
#  81749,
#  81750,
#  81761,
#  81769,
#  81776,
#  81781,
#  81783,
#  81784,
#  81808,
#  81810,
#  81815,
#  81832,
#  81837,
#  81838,
#  81842,
#  81845,
#  81847,
#  81856,
#  81868,
#  81869,
#  81878,
#  81884,
#  81893,
#  81906,
#  81917,
#  81918,
#  81935,
#  81940,
#  81941,
#  81947,
#  81952,
#  81953,
#  81961,
#  81962,
#  81970,
#  81972,
#  81976,
#  81981,
#  81983,
#  81988,
#  81990,
#  81997,
#  82015,
#  82017,
#  82021,
#  82029,
#  82035,
#  82038,
#  82039,
#  82043,
#  82056,
#  82063,
#  82067,
#  82082,
#  82084,
#  82089,
#  82093]

# %%
df_x.iloc[random.choice(ids)].values
# Out:
# array([17.        ,  2.29666519,  2.49136169,  1.        ,  5.62401751,
#        15.24348415, 15.01932077,  1.60943791, 16.62875868,  5.56068163,
#         5.56068163,  5.56068163,  1.        ,  5.56068163, 13.52333842,
#         3.        ])

# %%
df_y[81443]
# Out:
# 127.0

# %%
df_y[81503]
# Out:
# 128.0

# %%
df_y[81979]
# Out:
# 125.0

# %%
el = df_x.loc[[random.choice(ids)]].values

# %%
el
# Out:
# array([[19.        ,  0.47712125,  2.79169065,  3.        ,  9.36460533,
#         10.29339899,  9.93316771,  0.69314718, 10.62631489,  7.44190673,
#          7.44190673,  7.44190673,  1.        ,  7.44190673, 13.7336669 ,
#          2.        ]])

# %%
model = tf.keras.models.load_model('./best-model-07.01')

# %%
el = random.choice(ids)

# %%
model.predict(df_x.loc[[random.choice(ids)]].values)
# Out:
# array([[150.99661]], dtype=float32)

# %%
df_y[el]
# Out:
# 141.0

# %%
ram_list = list(range(128, 3072 ,64))
128	$0.0000000021
512	$0.0000000083

0.000000834
1024	$0.0000000167
1536	$0.0000000250
2048	$0.0000000333

# %%
0.0000166667 * 512/1024 /10
# Out:
# 8.33335e-07

# %%
for ram in ram_list:      
    price_per_100ms = 0.0000166667 * ram/1024 /10
    print("\"" + str(ram) + "\": {:.8f},".format(price_per_100ms))
# Out:
# "128": 0.00000021,
# "192": 0.00000031,
# "256": 0.00000042,
# "320": 0.00000052,
# "384": 0.00000063,
# "448": 0.00000073,
# "512": 0.00000083,
# "576": 0.00000094,
# "640": 0.00000104,
# "704": 0.00000115,
# "768": 0.00000125,
# "832": 0.00000135,
# "896": 0.00000146,
# "960": 0.00000156,
# "1024": 0.00000167,
# "1088": 0.00000177,
# "1152": 0.00000188,
# "1216": 0.00000198,
# "1280": 0.00000208,
# "1344": 0.00000219,
# "1408": 0.00000229,
# "1472": 0.00000240,
# "1536": 0.00000250,
# "1600": 0.00000260,
# "1664": 0.00000271,
# "1728": 0.00000281,
# "1792": 0.00000292,
# "1856": 0.00000302,
# "1920": 0.00000313,
# "1984": 0.00000323,
# "2048": 0.00000333,
# "2112": 0.00000344,
# "2176": 0.00000354,
# "2240": 0.00000365,
# "2304": 0.00000375,
# "2368": 0.00000385,
# "2432": 0.00000396,
# "2496": 0.00000406,
# "2560": 0.00000417,
# "2624": 0.00000427,
# "2688": 0.00000438,
# "2752": 0.00000448,
# "2816": 0.00000458,
# "2880": 0.00000469,
# "2944": 0.00000479,
# "3008": 0.00000490,

# %%
def custom_loss_function(y_actual, y_predicted):
    mask = tf.cast(tf.math.greater_equal(y_actual, y_predicted), tf.float32)
    mask = mask * 0.1 + 1
    y_actual = tf.math.multiply(y_actual, mask)
    return K.mean(K.square(K.abs(y_actual - y_predicted)))

# %%
actual = tf.constant([1.0, 3.0])
predicted = tf.constant([ 2.0, 1.0])
custom_loss_function(actual, predicted)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.1450005>
