# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

import keras
import sys
import keras.losses
import tensorflow as tf
import  keras.backend as  K
from scipy.stats import gaussian_kde
import seaborn as sns
from tensorflow.python.keras import losses
# Out:
# Using TensorFlow backend.

# %%
def data_all():
    
    df_x = pd.read_csv('x_final.csv')
    df_y = pd.read_csv('y_final.csv')

    x = df_x.values
    y = df_y.values

    x = np.asarray(x).astype('float32')
    y = np.asarray(y).astype('float32')
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)
    return x, y

# %%
x[:10,:]
# Out:
# array([[0.08889, 1.     , 0.     , 0.14286, 0.00729, 0.81598, 0.87042,
#         0.29865, 0.64322, 0.00354, 0.00354, 0.00354, 0.     , 0.00333,
#         0.     , 0.     ],
#        [0.08889, 0.70279, 0.     , 0.57143, 0.20988, 0.81564, 0.82513,
#         0.25724, 0.56337, 0.89621, 0.89621, 0.89621, 1.     , 0.90246,
#         0.98869, 0.     ],
#        [0.08889, 1.     , 0.     , 0.14286, 0.00729, 0.81632, 0.87062,
#         0.29865, 0.64346, 0.00179, 0.00179, 0.00179, 0.     , 0.00168,
#         0.     , 0.     ],
#        [0.08889, 0.70279, 0.     , 0.57143, 0.20988, 0.81598, 0.82533,
#         0.25724, 0.56361, 0.8964 , 0.8964 , 0.8964 , 1.     , 0.90264,
#         0.98869, 0.     ],
#        [0.08889, 1.     , 0.     , 0.14286, 0.00729, 0.81598, 0.87052,
#         0.29865, 0.64334, 0.00285, 0.00285, 0.00285, 0.     , 0.00267,
#         0.     , 0.     ],
#        [0.08889, 0.70279, 0.     , 0.57143, 0.20988, 0.81598, 0.82533,
#         0.25724, 0.56361, 0.8964 , 0.8964 , 0.8964 , 1.     , 0.90264,
#         0.98869, 0.     ],
#        [0.08889, 1.     , 0.     , 0.14286, 0.00729, 0.81632, 0.87072,
#         0.29865, 0.64358, 0.0032 , 0.0032 , 0.0032 , 0.     , 0.003  ,
#         0.     , 0.     ],
#        [0.08889, 1.     , 0.     , 0.14286, 0.00729, 0.81598, 0.87042,
#         0.29865, 0.64322, 0.0032 , 0.0032 , 0.0032 , 0.     , 0.003  ,
#         0.     , 0.     ],
#        [0.08889, 0.70279, 0.     , 0.57143, 0.20988, 0.81598, 0.82533,
#         0.25724, 0.56361, 0.8964 , 0.8964 , 0.8964 , 1.     , 0.90264,
#         0.98869, 0.     ],
#        [0.08889, 1.     , 0.     , 0.14286, 0.00729, 0.81598, 0.87052,
#         0.29865, 0.64334, 0.00492, 0.00492, 0.00492, 0.     , 0.00463,
#         0.     , 0.     ]], dtype=float32)

# %%
best_model = keras.models.load_model('./best-256-run-normalized')

y_pred = best_model.predict(x)
np.set_printoptions(precision=5)
np.set_printoptions(threshold=sys.maxsize)
test_vs_pred = np.concatenate((y_pred.reshape(len(y_pred), 1), y.reshape(len(y),1)), 1)*30

dataset = pd.DataFrame({'x_ram': x[:, 0] * (3008 -  128) + 128,
                    'x_task': x[:,3]*7,
                    'x_workflow': x[:,-1]*2 + 1,
                    'y_test': test_vs_pred[:, 1],
                    'y_pred': test_vs_pred[:, 0],
                    'avg_in' : x[:, 6],
                    'count_in' : x[:, 7],
                    'avg_out' : x[:, 12],
                    'count_out' : x[:, 13]})
df = dataset[(dataset['x_task'] == 1) & (dataset['x_workflow'] == 1.0) & (dataset['x_ram'] == 256)]
print(df)
plt.figure (figsize=(10,10))
ax = df.plot(kind = 'scatter', x = 'x_ram',
                  y = 'y_test', color = 'Blue', figsize=(15,15), label="Real")

ax2 = df.plot(kind = 'scatter', x = 'x_ram', 
                   y = 'y_pred',
                   color = 'Red',
                   ax = ax, figsize=(15,15), label="Predicted")
# Out:
#       x_ram  x_task  x_workflow    y_test    y_pred    avg_in  count_in  \
# 1597  256.0     1.0         1.0  1.769850  1.871256  0.870420  0.298648
# 1599  256.0     1.0         1.0  3.039978  1.567827  0.870620  0.298648
# 1601  256.0     1.0         1.0  2.266449  1.753047  0.870520  0.298648
# 1603  256.0     1.0         1.0  2.207107  1.812295  0.870721  0.298648
# 1604  256.0     1.0         1.0  1.957246  1.812314  0.870420  0.298648
# ...     ...     ...         ...       ...       ...       ...       ...
# 2385  256.0     1.0         1.0  1.463770  1.930041  0.870921  0.298648
# 2386  256.0     1.0         1.0  3.787479  1.930041  0.870921  0.298648
# 2387  256.0     1.0         1.0  1.194128  1.567747  0.870520  0.298648
# 2389  256.0     1.0         1.0  1.486674  1.693843  0.870620  0.298648
# 2390  256.0     1.0         1.0  1.296155  1.930060  0.870620  0.298648
#
#       avg_out  count_out
# 1597      0.0   0.003331
# 1599      0.0   0.001681
# 1601      0.0   0.002675
# 1603      0.0   0.003003
# 1604      0.0   0.003003
# ...       ...        ...
# 2385      0.0   0.003657
# 2386      0.0   0.003657
# 2387      0.0   0.001681
# 2389      0.0   0.002345
# 2390      0.0   0.003657
#
# [654 rows x 9 columns]

# %%
def show_results(best_model, x, y):
    y_pred = best_model.predict(x)
    np.set_printoptions(precision=5)
    np.set_printoptions(threshold=sys.maxsize)
    test_vs_pred = np.concatenate((y_pred.reshape(len(y_pred), 1), y.reshape(len(y),1)), 1)*30
    
    print("MAE: " + str(mean_absolute_error(y_pred, y)))
    print("MSE: " + str(mean_squared_error(y_pred, y)))
    print("RMSE: " + str(mean_squared_error(y_pred, y, squared=False)))
    print("R2 SCORE: " + str(r2_score(y_pred, y)))
    
    dataset = pd.DataFrame({'x_ram': (x[:, 0] * (3008 -  128) + 128).astype(int),
                        'x_task': x[:,3]*7,
                        'x_workflow': x[:,-1]*2 + 1,
                        'y_test': test_vs_pred[:, 0],
                        'Time': 'Real'})
    
    dataset = pd.concat([pd.DataFrame({'x_ram': (x[:, 0] * (3008 -  128) + 128).astype(int),
                    'x_task': x[:,3]*7,
                    'x_workflow': x[:,-1]*2 + 1,
                    'y_test': test_vs_pred[:, 1],
                    'Time': 'Predicted'}), dataset])
    
    for task_type in range(0,8):

        df = dataset[(dataset['x_task'] == task_type) & (dataset['x_workflow'] == 1.0)]
        fig, ax = plt.subplots()
        fig.set_size_inches(15, 15)
        
        rotateTickLabels(ax, 90, 'x')

        scatter = sns.stripplot(data =df, x="x_ram", y="y_test", hue="Time", dodge=True, jitter=0.2, size=2)
    
                    

#         ax = df.plot(kind = 'scatter', x = 'x_ram',
#                           y = 'y_test', figsize=(15,15), label="Real", c=full_z)

#         ax2 = df.plot(kind = 'scatter', x = 'x_ram', 
#                            y = 'y_pred',
#                            color = 'Red',
#                            ax = ax, figsize=(15,15), label="Predicted")

# %%
def rotateTickLabels(ax, rotation, which, rotation_mode='anchor', ha='right'):
    axes = []
    if which in ['x', 'both']:
        axes.append(ax.xaxis)

    elif which in ['y', 'both']:
        axes.append(ax.yaxis)

    for axis in axes:
        for t in axis.get_ticklabels():
            t.set_horizontalalignment(ha)
            t.set_rotation(rotation)
            t.set_rotation_mode(rotation_mode)

# %%
def custom_loss_function(y_actual, y_predicted):
    mask = tf.cast(tf.math.greater_equal(y_actual, y_predicted), tf.float32)
    mask = mask*3 + 1
    y_predicted = tf.math.divide(y_predicted, mask)
    return K.mean(K.sum(K.abs(y_predicted - y_actual)))

# %%
def tilted_loss(q,y,f):
    e = (y-f)
    return K.mean(K.maximum(q*e, (q-1)*e), axis=-1)

# %%
def gaussianSum1D(gridpoints, datapoints, sigma=1):

    a = np.exp( -((gridpoints[:,None]-datapoints)/sigma)**2 )

    return a

# %%
x, y = data_all()

# %%
show_results(keras.models.load_model('./best-model-final'), x, y)
# Out:
# MAE: 0.005579534
# MSE: 9.230315e-05
# RMSE: 0.009607453
# R2 SCORE: 0.9971898851414104

# %%
show_results(keras.models.load_model('./best-model-hyperflow-v3'), x, y)
# Out:
# MAE: 0.006966621
# MSE: 0.00015294629
# RMSE: 0.012367145
# R2 SCORE: 0.995385238000001

# %%
show_results(tf.keras.models.load_model('./best-model-hyperflow-v4'),  x, y)
# Out:
# MAE: 0.007747617
# MSE: 0.00016938757
# RMSE: 0.013014898
# R2 SCORE: 0.9949966909646446

# %%
show_results(keras.models.load_model('./best-model-hyperflow'), x, y)
# Out:
# MAE: 0.0068426854
# MSE: 0.00015506466
# RMSE: 0.012452496
# R2 SCORE: 0.9953834911705852

# %% [markdown]
# Execution 256 ram

# %%
show_results(keras.models.load_model('./best-256-run-normalized'), x, y)
# Out:
# MAE: 0.0054286877
# MSE: 0.0001455743
# RMSE: 0.012065418
# R2 SCORE: 0.9956316177300188

# %% [markdown]
# Execution of montage 0.35 every 128 ram

# %%
show_results(keras.models.load_model('./best-half-run-normalized'), x, y)
# Out:
# MAE: 0.0056759217
# MSE: 0.00014544511
# RMSE: 0.012060063
# R2 SCORE: 0.9956422654152643

# %% [markdown]
# One whole execution of montage 0.35 every 64 ram

# %%
show_results(keras.models.load_model('./best-one-run-normalized'), x, y)
# Out:
# MAE: 0.0053284685
# MSE: 0.00014065931
# RMSE: 0.011859988
# R2 SCORE: 0.995724580180179

# %% [markdown]
# WHOLE
# {'Dense': 50, 'Dense_1': 90, 'Dense_2': 90, 'Dropout': 0.02265866228192772, 'Dropout_1': 0.027089589588407712, 'Dropout_2': 0.038647175058504936, 'batch_size': 256, 'epochs': 750, 'optim': 0}

# %% [markdown]
# HALF
# {'Dense': 50, 'Dense_1': 70, 'Dense_2': 90, 'Dropout': 0.02265866228192772, 'Dropout_1': 0.027089589588407712, 'Dropout_2': 0.038647175058504936, 'batch_size': 128, 'epochs': 1000, 'optim': 0}

# %% [markdown]
# 256: {'Dense': 90, 'Dense_1': 70, 'Dense_2': 50, 'Dropout': 0.051599490133013515, 'Dropout_1': 0.09806548146765555, 'Dropout_2': 0.043093002872203676, 'batch_size': 256, 'epochs': 750, 'optim': 0}

# %%
import sys
y_pred = best_model.predict(x)
np.set_printoptions(precision=5)
np.set_printoptions(threshold=sys.maxsize)
test_vs_pred = np.concatenate((y_pred.reshape(len(y_pred), 1), y.reshape(len(y),1)), 1)*30

# %%
mean_absolute_error(y_pred, y)
# Out:
# 0.0053284685

# %%
mean_squared_error(y_pred, y)
# Out:
# 0.00014065931

# %%
dataset = pd.DataFrame({'x_ram': x[:, 0] * (3008 -  128) + 128,
                        'x_task': x[:,3]*7,
                        'x_workflow': x[:,-1]*2 + 1,
                        'y_test': test_vs_pred[:, 1],
                        'y_pred': test_vs_pred[:, 0]})

# %%
df = dataset[(dataset['x_task'] == 2) & (dataset['x_workflow'] == 1.0)]
plt.figure (figsize=(10,10))
ax = df.plot(kind = 'scatter', x = 'x_ram',
                  y = 'y_test', color = 'Blue', figsize=(10,10))
  
ax2 = df.plot(kind = 'scatter', x = 'x_ram', 
                   y = 'y_pred',
                   color = 'Red',
                   ax = ax, figsize=(10,10))
